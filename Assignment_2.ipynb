# %% [markdown]
# <a href="https://colab.research.google.com/github/AyushKushwaha2510/Python-Lectures/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name - Ayush Kumar Kushwaha
# # Roll - 2024UG1020
# # Section - A
# # Assignment Title - Functions with NumPy and Matplotlib

# %% [markdown]
# # Imports

# %%
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
uploaded = files.upload() # upload the file
df = pd.read_csv('Final_data.csv') # read the file
df.head()

# %% [markdown]
# # Quick Peeks at Columns

# %%
list(df.column)

# %% [markdown]
# # **🔹 Part A: Basic Functions (Q1 – Q6)**

# %% [markdown]
# **Q1.** Write a function welcome() that prints:
# "Welcome to Python Fitness Tracker 󰝮" Call the function 3 times.
#
# ![image.png](data:image/png;base64,...)

# %%
# funtion declare
def welcome():
  print("Welcome to Python Fitness Tracker")

# calling function 3 times
for i in range(3):
  welcome()

# %% [markdown]
# **Q2.** Write a function bmi(weight, height) that returns the Body Mass Index (BMI).
# Formula: BMI = weight / height**2
# Example: print(bmi(68, 1.75))
#
# ![image.png](data:image/png;base64,...)

# %%
def bmi(weight, height):
  return weight / height**2

print(bmi(68, 1.75))

# %% [markdown]
# **Q3.** Write a function calories_burned(duration, rate=10) that returns total calories as duration * rate.
# Call the function once with one argument and once with both arguments.
#
# ![image.png](data:image/png;base64,...)

# %%
def calories_burned(duration, rate=10):
  return duration * rate

print(calories_burned(30))
print(calories_burned(30, 15))

# %% [markdown]
# **Q4.** Create a function heart
# rate
# _
# _
# stats(max
# _
# bpm, avg_
# bpm, resting_
# bpm) that returns:
#
# ●
# Heart Rate Reserve = max
# _
# bpm - resting_
# bpm
#
# ●
# Average Difference = avg_
# bpm - resting_
# bpm
# Print both returned values separately.
#
# ![image.png](data:image/png;base64,...)

# %%
def heart_rate_stats(max_bpm, avg_bpm, resting_bpm):
    # Calculate Heart Rate Reserve
    heart_rate_reserve = max_bpm - resting_bpm

    # Calculate Average Difference
    average_difference = avg_bpm - resting_bpm

    # Return both values
    return heart_rate_reserve, average_difference


# Example usage
max_bpm = 190
avg_bpm = 130
resting_bpm = 70

# Get the results
hr_reserve, avg_diff = heart_rate_stats(max_bpm, avg_bpm, resting_bpm)

# Print the results separately
print("Heart Rate Reserve:", hr_reserve)
print("Average Difference:", avg_diff)

# %% [markdown]
# **Q5.** Write a function workout
# _
# summary(name, duration, type='Cardio'
# , calories=500) that prints:
# "Amit completed 1.2 hours of Cardio and burned 500 calories.
# " Call it using keyword arguments in
# random order.
#
# ![image.png](data:image/png;base64,...)

# %%
def workout_summary(name, duration, type='Cardio', calories=500):
  # printing the sentence
  print(f"{name} completed {duration} hours of {type} and burned {calories} calories.")


# Call the function using keyword arguments in random order
workout_summary(calories=500, name="Amit", duration=1.2, type="Cardio")

# %% [markdown]
# **Q6.** Create two functions:
#
# ●
# add
# _
# calories(c1, c2) that returns sum of calories.
#
# ●
# weekly_
# burn() that calls add
# _
# calories() 7 times for each day’s burn.
# Print total burn.
#
# ![image.png](data:image/png;base64,...)

# %%
# Function to add calories burned
def add_calories(c1, c2):
    # Return sum of calories
    return c1 + c2

# Function to calculate weekly calories burned
def weekly_burn(week):
    total = 0
    for day in week:
        total += add_calories(day[0], day[1])
    return total

# Example data: calories burned in two sessions per day for 7 days
week_data = [
    [1, 2],   # Day 1
    [3, 4],   # Day 2
    [1, 2],   # Day 3
    [5, 6],   # Day 4
    [3, 4],   # Day 5
    [6, 7],   # Day 6
    [9, 2]    # Day 7
]

# Print total weekly calories burned
print("Total Weekly Burn:", weekly_burn(week_data))

# %% [markdown]
# #**🔹 Part B:** Intermediate Functions (Q7 – Q13)

# %% [markdown]
# **Q7.** Write a function fitness
# _profile(name, weight, height, age) that prints all details.
# Call it once using positional and once using keyword arguments.
#
# ![image.png](data:image/png;base64,...)

# %%
def fitness_profile(name, weight, height, age):
  print("Name:", name)
  print("Weight:", weight)
  print("Height:", height)
  print("Age:", age)

# Using positional arguments
fitness_profile("Rakesh", 70, 175, 20)

print() # for a line break space

# Using keyword arguments
fitness_profile(name = "Ayush", age = 20, weight = 65, height = 179)

# %% [markdown]
# **Q8.** Write a function total
# Example: print(total
# _
# calories(*args) that returns the sum of all given calorie values.
# _
# calories(200, 300, 150, 400))
#
# ![image.png](data:image/png;base64,...)

# %%
def total_calories(*args):
  total = 0
  for calorie in args:  # looping through calories
      total += calorie
  return total

# printing total calories
print(total_calories(200, 300, 150, 400))

# %% [markdown]
# **Q9.** Define a function generate
# _profile(name, age, weight, height) that returns a dictionary with keys:
# Name, Age, Weight, Height, BMI.
#
# ![image.png](data:image/png;base64,...)

# %%
def generate_profile(name, age, weight, height):
  # Calculate BMI = weight / (height in meters)^2
  bmi = weight / (height ** 2)

  # Create a dictionary with all details
  profile = {
      "Name": name,
      "Age": age,
      "Weight": weight,
      "Height": height,
      "BMI": round(bmi, 2)   # rounded to 2 decimal places
  }

  return profile


user_profile = generate_profile("Amit", 20, 65, 1.75)
print(user_profile)

# %% [markdown]
# **Q10.** Create a global variable bonus = 100.
# Define a function calorie
# _
# reward(burn) that adds bonus to burn.
# Then redefine it using a local variable bonus = 200 and observe difference.
# ![image.png](data:image/png;base64,...)

# %%
bonus = 100
def calorie_reward(burn):
  bonus = 200
  return burn + bonus
calorie_reward(100)


# The difference in the two codes are,
# when using in local :
#   local bonus adds in burn
#   meaning , local over-rides global

# when using global :
#   global bonus adds in burn

# %% [markdown]
# **Q11.** Write a function calculate
# _
# HRR(max
# _
# bpm, resting_
# bpm, intensity=0.7) that returns Heart Rate
# Reserve zone.
#
# ![image.png](data:image/png;base64,...)

# %%
def calculate_HRR(max_bpm, resting_bpm, intensity=0.7):
  return (max_bpm - resting_bpm) * intensity # calulation & return

calculate_HRR(180, 60) # calling of function

# %% [markdown]
# **Q12.** Write a function daily_
# burns(calories
# _
# list) that prints burn for each day and returns total.
#
# ![image.png](data:image/png;base64,...)

# %%
def daily_burns(calories_list):
    total = 0
    day_num = 0
    week = ['Monday', 'Tuesday', 'Wednesday', 'Thrusday', 'Friday', 'Saturday', 'Sunday']

    # Loop through each day's calories
    for calories in calories_list:
        print(f"{week[day_num]} burn: {calories} calories")
        total += calories
        day_num += 1

    # Return total burn at the end
    return total


# Example usage
week_calories = [200, 300, 250, 400, 350, 500, 450]
total_burn = daily_burns(week_calories)

print("\nTotal Weekly Burn:",  total_burn)

# %% [markdown]
# **Q13.** Define a function filter
# _
# high
# _
# calories(calories, threshold) that returns all values > threshold.
# Use list comprehension inside.
#
# ![image.png](data:image/png;base64,...)

# %%
def filter_high_calories(calories, threshold):
  return [cal for cal in calories if cal > threshold]

week_calories = [200, 300, 250, 400, 350, 500, 450]

filter_high_calories(week_calories, 300)

# %% [markdown]
# # **🔹 Part C:** Advanced Concepts (Q14 – Q20)

# %% [markdown]
# **Q14.** Create a lambda function for BMI:
# bmi = lambda w, h: w / (h ** 2)
# Print result for (70, 1.75).
#
# ![image.png](data:image/png;base64,...)

# %%
# Lambda function to calculate BMI
bmi = lambda w, h: w / (h ** 2)


print("BMI:", round(bmi(70, 1.75), 2))

# %% [markdown]
# **Q15.** Write a function square(n) and apply it using map() on [2,4,6,8].
# Print squared results.
# ![image.png](data:image/png;base64,...)

# %%
def square(n):
  return n*n

# calling function using map
list(map(square, [2,4,6,8]))

# %% [markdown]
# **Q16.** Write a function is
# _
# high
# _
# burn(x) that returns True if x > 1000.
# Use filter() on list [800, 1200, 950, 1500, 700, 2000].
#
# ![image.png](data:image/png;base64,...)

# %%
def high_burn(x):
  return x > 1000

# calling function using filter
list(filter(high_burn, [800, 1200, 950, 1500, 700, 2000]))

# %% [markdown]
# **Q17.** Write a recursive function sum
# _
# n(n) to return sum of first n natural numbers.
# Call sum
# _
# n(100).
#
# ![image.png](data:image/png;base64,...)

# %%
def sum_n(n):
    # Base case
    if n == 1:
        return 1
    else:
        # Recursive case
        return n + sum_n(n - 1)

print("Sum of first 100 natural numbers:", sum_n(100))

# %% [markdown]
# **Q18.** Write a recursive function factorial(n) to return n!
# Call factorial(6).
# ![image.png](data:image/png;base64,...)

# %%
def factorial(n):
  # Base case
  if n == 1:
    return 1
  else:
    # Recursive case
    return n * factorial(n-1)

print(f"Factorial of {6} is {factorial(6)}")

# %% [markdown]
# **Q19.** Write a function mean
# _
# std(array) that returns mean and standard deviation using NumPy.
#
# Test: import numpy as np
#
# data = np.array([10,20,30,40,50])
#
# print(mean
# _
# std(data))
# ![image.png](data:image/png;base64,...)

# %%
def mean_std(array):
  mean = np.mean(array) # mean calculation
  std = np.std(array) # std. deviation calculation
  return mean, std

data = np.array([10, 20, 30, 40, 50])
print(mean_std(data))

# %% [markdown]
# Q20. Write a function plot
# _
# workout(time, calories) that plots a line chart using Matplotlib with:
#
# ●
# X-axis = time
#
# ●
# Y-axis = calories
#
# ●
# Title = "Workout Efficiency Tracker"
# ![image.png](data:image/png;base64,...)

# %%
def plot_workout(time, calories):
    plt.plot(time, calories, marker='o', linestyle='-', color='b')

    # graph tile
    plt.title("Workout Efficiency Tracker")

    # x-axis label
    plt.xlabel("Time (minutes)")

    # y-axis label
    plt.ylabel("Calories Burned")

    # toggle grids
    plt.grid(True)

    # show the graph
    plt.show()

# Example test data
time = [10, 20, 30, 40, 50]
calories = [50, 120, 200, 280, 360]

plot_workout(time, calories)

# %% [markdown]
# #**🔹 Bonus Section (Q21 – Q25)**

# %% [markdown]
# **Q21.** Write a function to return top 5 calorie burners from your dataset (Final
# _
# data.csv).
# ![image.png](data:image/png;base64,...)

# %%
def top_5_burners(filename):
    # Read the dataset
    data = pd.read_csv(filename)

    # Sort data by 'Calories' column in descending order
    top_5 = data.sort_values(by='Calories', ascending=False).head(5)

    # Return top 5 rows
    return top_5

# Example usage
top_burners = top_5_burners('Final_data.csv')
print(top_burners)

# %% [markdown]
# **Q22.** Write a function to calculate and print average heart rate by gender.
# ![image.png](data:image/png;base64,...)

# %%
def avg_heart_rate_by_gender(df):
    # Group by Gender and calculate mean of Heart_Rate
    avg_hr = df.groupby('Gender')['Avg_BPM'].mean()
    print("Average Heart Rate by Gender:")
    print(avg_hr)


avg_heart_rate_by_gender(df)

# %% [markdown]
# **Q23.** Write a function to visualize Calories
# Burned vs Session
# Duration for each Workout
# _
# _
# _
# Matplotlib.
# ![image.png](data:image/png;base64,...)

# %%
def plot_calories_vs_duration(df):
    # Create scatter plot for each Workout_Type
    types = df['Workout_Type'].unique()
    for t in types:
        subset = df[df['Workout_Type'] == t].copy() # Use .copy() to avoid SettingWithCopyWarning
        # Convert hours to minutes for plotting
        subset['Session_Duration_minutes'] = subset['Session_Duration (hours)'] * 60
        plt.scatter(subset['Session_Duration_minutes'], subset['Calories_Burned'], label=t)

    plt.title("Calories Burned vs Session Duration")
    plt.xlabel("Session Duration (min)")
    plt.ylabel("Calories Burned")
    plt.legend()
    plt.grid(True)
    plt.show()

# Example call
plot_calories_vs_duration(df)

# %% [markdown]
# **Q24.** Write a function to compute correlation between any two numeric columns (column names taken
# from user input).
#
# ![image.png](data:image/png;base64,...)

# %%
def column_correlation(df):
    # Ask user to input column names
    col1 = input("Enter first column name: ")
    col2 = input("Enter second column name: ")

    # Check if both columns exist in the DataFrame
    if col1 in df.columns and col2 in df.columns:
        # Check if both columns are numeric
        if pd.api.types.is_numeric_dtype(df[col1]) and pd.api.types.is_numeric_dtype(df[col2]):
            corr = df[col1].corr(df[col2])
            print(f"Correlation between '{col1}' and '{col2}': {round(corr, 2)}")
        else:
            print("One or both columns are not numeric.")
    else:
        print("Invalid column names. Please check spelling and try again.")


column_correlation(df)

# %% [markdown]
# **Q25.** Write a function that creates and saves any Matplotlib plot as a PNG file automatically.
# ![image.png](data:image/png;base64,...)

# %%
def save_plot_as_png(x, y, filename='workout_plot.png'):
    plt.plot(x, y, marker='o')
    plt.title("Workout Summary")
    plt.xlabel("X-axis")
    plt.ylabel("Y-axis")
    plt.grid(True)
    plt.savefig(filename)
    print(f"Plot saved as {filename}")


save_plot_as_png([1, 2, 3, 4], [100, 200, 250, 300])
